# %%
# !pip install builtwith
# Out:
# ...
# distributed 1.21.8 requires msgpack, which is not installed.

# %%
import builtwith
#사용된 웹 기술 확인

# %%
builtwith.parse("http://www.google.com")
# Out:
# {'web-servers': ['Google Web Server']}

# %%
builtwith.parse("http://www.facebook.com")

# %%
builtwith.parse("http://www.naver.com")
# Out:
# {}

# %%
builtwith.parse("http://www.wordpress.com")
# Out:
# {'web-servers': ['Nginx'],
#  'font-scripts': ['Google Font API'],
#  'ecommerce': ['WooCommerce'],
#  'cms': ['WordPress'],
#  'programming-languages': ['PHP'],
#  'blogs': ['PHP', 'WordPress']}

# %%
builtwith.parse("http://www.daum.net")
# Out:
# {}

# %%
# !pip install python-whois
# Out:
# ...
#   Running setup.py bdist_wheel for python-whois: started
#   Running setup.py bdist_wheel for python-whois: finished with status 'done'
#   Stored in directory: C:\Users\4men8\AppData\Local\pip\Cache\wheels\06\cb\7d\33704632b0e1bb64460dc2b4dcc81ab212a3d5e52ab32dc531
#   Running setup.py bdist_wheel for future: started
#   Running setup.py bdist_wheel for future: finished with status 'done'
#   Stored in directory: C:\Users\4men8\AppData\Local\pip\Cache\wheels\bf\c9\a3\c538d90ef17cf7823fa51fc701a7a7a910a80f6a405bf15b1a
# Successfully built python-whois future
# ...
# distributed 1.21.8 requires msgpack, which is not installed.

# %%
import whois
#웹사이트 소유자 정보 확인

# %%
print(whois.whois("naver.com"))
# Out:
# {
#   "domain_name": [
#     "NAVER.COM",
#     "naver.com"
#   ],
#   "registrar": "Gabia, Inc.",
#   "whois_server": "whois.gabia.com",
#   "referral_url": null,
#   "updated_date": [
#     "2016-08-05 06:37:57",
#     "2018-02-28 11:27:15"
#   ],
#   "creation_date": [
#     "1997-09-12 04:00:00",
#     "1997-09-12 00:00:00"
#   ],
#   "expiration_date": [
#     "2023-09-11 04:00:00",
#     "2023-09-11 00:00:00"
#   ],
#   "name_servers": [
#     "NS1.NAVER.COM",
#     "NS2.NAVER.COM",
#     "ns1.naver.com",
#     "ns2.naver.com"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited",
#     "ok https://icann.org/epp#ok"
#   ],
#   "emails": [
#     "white.4818@navercorp.com",
#     "dl_ssl@navercorp.com",
#     "abuse@gabia.com"
#   ],
#   "dnssec": "unsigned",
# ...

# %%
print(whois.whois("appspo.com"))
# Out:
# {
#   "domain_name": [
#     "APPSPO.COM",
#     "appspo.com"
#   ],
#   "registrar": "GoDaddy.com, LLC",
#   "whois_server": "whois.godaddy.com",
#   "referral_url": null,
#   "updated_date": [
#     "2017-07-26 00:18:09",
#     "2017-07-26 00:09:20"
#   ],
#   "creation_date": "2017-07-26 00:09:19",
#   "expiration_date": "2018-07-26 00:09:19",
#   "name_servers": [
#     "NS1.PARKINGCREW.NET",
#     "NS2.PARKINGCREW.NET"
#   ],
#   "status": [
#     "clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited",
#     "clientRenewProhibited https://icann.org/epp#clientRenewProhibited",
#     "clientTransferProhibited https://icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited",
#     "clientTransferProhibited http://www.icann.org/epp#clientTransferProhibited",
#     "clientUpdateProhibited http://www.icann.org/epp#clientUpdateProhibited",
# ...

# %%
whois.whois("korea.org")
# Out:
# {'domain_name': 'KOREA.ORG',
#  'registrar': 'Gabia Inc.',
#  'whois_server': None,
#  'referral_url': None,
#  'updated_date': datetime.datetime(2015, 1, 2, 13, 10, 6),
#  'creation_date': datetime.datetime(1996, 2, 5, 5, 0),
#  'expiration_date': datetime.datetime(2020, 2, 6, 5, 0),
#  'name_servers': ['NS.DSDN.NET', 'NS.ICASH.CO.KR'],
#  'status': 'ok https://icann.org/epp#ok',
#  'emails': None,
#  'dnssec': 'unsigned',
#  'name': None,
#  'org': None,
#  'address': None,
#  'city': None,
#  'state': None,
#  'zipcode': None,
#  'country': 'KR'}

# %%
whois.whois("http://www.seikokorea.com/")
# Out:
# {'domain_name': ['SEIKOKOREA.COM', 'seikokorea.com'],
#  'registrar': 'INAMES CO., LTD.',
#  'whois_server': 'whois.inames.co.kr',
#  'referral_url': None,
#  'updated_date': [datetime.datetime(2017, 10, 27, 9, 45, 51),
#   datetime.datetime(2017, 10, 27, 9, 45, 52)],
#  'creation_date': datetime.datetime(2014, 3, 11, 0, 23, 17),
#  'expiration_date': datetime.datetime(2024, 9, 18, 11, 59, 59),
#  'name_servers': ['NS.GETHOMPY.COM',
#   'NS1.GETHOMPY.COM',
#   'NS2.GETHOMPY.COM',
#   'NS3.GETHOMPY.COM',
#   'ns.gethompy.com',
#   'ns1.gethompy.com',
#   'ns2.gethompy.com',
#   'ns3.gethompy.com'],
#  'status': ['clientTransferProhibited https://icann.org/epp#clientTransferProhibited',
#   'ok http://icann.org/epp#OK'],
#  'emails': ['abuse@inames.co.kr', 'seikomaster@seikokorea.co.kr'],
#  'dnssec': ['unsigned', 'Unsigned'],
#  'name': 'SAMJUNGWATCH CO., LTD.',
#  'org': 'SAMJUNGWATCH CO., LTD.',
#  'address': 'SJ Building 21 Eonju-ro 126-gil Gangnam-gu',
#  'city': 'Seoul',
# ...

# %% [markdown]
# # 스크래핑

# %%
from urllib.request import urlopen

# %%
req = urlopen("http://python.org")

# %%
text = req.read().decode("utf-8")

# %%
text
# Out:
# '<!doctype html>\n<!--[if lt IE 7]>   <html class="no-js ie6 lt-ie7 lt-ie8 lt-ie9">   <![endif]-->\n<!--[if IE 7]>      <html class="no-js ie7 lt-ie8 lt-ie9">          <![endif]-->\n<!--[if IE 8]>      <html class="no-js ie8 lt-ie9">                 <![endif]-->\n<!--[if gt IE 8]><!--><html class="no-js" lang="en" dir="ltr">  <!--<![endif]-->\n\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n\n    <link rel="prefetch" href="//ajax.googleapis.com/ajax/libs/jquery/1.8.2/jquery.min.js">\n\n    <meta name="application-name" content="Python.org">\n    <meta name="msapplication-tooltip" content="The official home of the Python Programming Language">\n    <meta name="apple-mobile-web-app-title" content="Python.org">\n    <meta name="apple-mobile-web-app-capable" content="yes">\n    <meta name="apple-mobile-web-app-status-bar-style" content="black">\n\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <meta name="H
# ...

# %%
resp = urlopen("http://www.google.com")

# %%
resp.read().decode("utf-8")
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="6wuGE8zgUwzfrhOFgbWzGg==">(function(){window.google={kEI:\'zxxMW6jGIs7o0gTC4p24Cg\',kEXPI:\'0,1353747,57,884,486,588,1017,280,336,160,215,128,260,1251,607,187,135,130,2339594,235,192,32,329294,1294,12383,2348,2507,32692,15247,867,42,1538,7,4470,635,5471,5281,11240,367,550,664,326,1776,113,1150,1051,3191,726,5,1702,66,71,132,3129,1978,575,1119,2,544,1,7,26,728,311,1757,154,209,1362,1712,1376,505,730,377,1240,479,608,686,8,1569,222,1784,1016,283,2,2825,758,878,525,22,604,2,153,506,1641,41,152,3,933,321,77,29,272,141,473,283,509,955,632,296,447,196,704,397,205,263,11,43,18,1,16,162,47,287,123,7,1118,107,14,105,386,8,806,160,118,7,28,463,620,29,460,245,3,186,4,4,4,4,101,384,451,7,62,217,302,50,212,58,6,567,7
# ...

# %%
resp = urlopen("http://www.naver.com")

# %%
resp.read().decode("utf-8")
# Out:
# '<!doctype html>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<html lang="ko" class="svgless">\n<head>\n<meta charset="utf-8">\n<meta name="Referrer" content="origin">\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="viewport" content="width=1100">\n<meta name="apple-mobile-web-app-title" content="NAVER" />\n<meta name="robots" content="index,nofollow"/>\n<meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>\n<meta property="og:title" content="네이버">\n<meta property="og:url" content="https://www.naver.com/">\n<meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png">\n<meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>\n<meta name="twitter:card" content="summary">\n<meta name="twitter:title" content="">\n<meta name="twitter:url" content="https://
# ...

# %%
from urllib.error import HTTPError

try:
    urlopen("https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=http+error")
except HTTPError as e:
    print(e.code, e.reason, e.headers)
# Out:
# 403 Forbidden Date: Mon, 16 Jul 2018 04:27:30 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: close
# Vary: Accept-Encoding
# Set-Cookie: page_uid=T0wPVlpySD8ssc+2XXGsssssscR-071568; path=/; domain=.naver.com
# Set-Cookie: _naver_usersession_=/edpCznrmV2ZbHrZKCFKHw==; path=/; expires=Mon, 16-Jul-18 04:32:30 GMT; domain=.naver.com
# X-Frame-Options: SAMEORIGIN
# X-XSS-Protection: 1; report=/p/er/post/xss
# Cache-Control: no-cache, no-store, must-revalidate, max-age=0
# Pragma: no-cache
# Vary: Accept-Encoding

# %%
#urllib로 크롤링 하는 방법~

from urllib.request import Request
from urllib.error import HTTPError

def download(url, agent="python bot",num_retries=2):
    headers = {"user-agent":agent}
    req = Request(url, headers=headers)

    try:
        resp = urlopen(req)
    except HTTPError as e:
        resp= None
        print(e.code, e.reason, e.headers)
        
        if 500<=e.code <600 and num_retries>0:
            return download(url,num_retries=num_retries-1)
        
        
    return resp;

# %%
html = download("http://httpstat.us/500")
# Out:
# 500 Internal Server Error Cache-Control: private
# Server: Microsoft-IIS/10.0
# X-AspNetMvc-Version: 5.1
# Access-Control-Allow-Origin: *
# X-AspNet-Version: 4.0.30319
# X-Powered-By: ASP.NET
# Set-Cookie: ARRAffinity=8d9742d8920fc8f87dbfb6e900a1f176e365d58296d2c5e44961e07bf1b65817;Path=/;HttpOnly;Domain=httpstat.us
# Date: Mon, 16 Jul 2018 04:37:57 GMT
# Connection: close
# Content-Length: 0
#
#
# 500 Internal Server Error Cache-Control: private
# Server: Microsoft-IIS/10.0
# X-AspNetMvc-Version: 5.1
# Access-Control-Allow-Origin: *
# X-AspNet-Version: 4.0.30319
# X-Powered-By: ASP.NET
# Set-Cookie: ARRAffinity=8d9742d8920fc8f87dbfb6e900a1f176e365d58296d2c5e44961e07bf1b65817;Path=/;HttpOnly;Domain=httpstat.us
# Date: Mon, 16 Jul 2018 04:37:57 GMT
# Connection: close
# Content-Length: 0
#
#
# 500 Internal Server Error Cache-Control: private
# Server: Microsoft-IIS/10.0
# X-AspNetMvc-Version: 5.1
# Access-Control-Allow-Origin: *
# X-AspNet-Version: 4.0.30319
# X-Powered-By: ASP.NET
# ...

# %%
#urllib로 크롤링 하는 방법~

agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36"

#agent 값을 찾아서 넣어줘야 속일 수 있어영(불법 조심) //f12>네트워크>>name 맨위에 클릭>>headers 하단부 user-agent 값
#비정상경로라 url 입력시, agent 값이 반듣시 필요해서 대충 떼우는 팁

html = download("https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=zzzzz",agent=agent)

# %%
html.read().decode("utf-8")
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="zzzzz : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'zzzzz\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'zzzzz\'의 네이버 통합검색 결과입니다."> <title>zzzzz : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_140327.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_180712.css"> <link rel="stylesheet" type="text/cs
# ...

# %%
#requests 크롤링 하는 방법~
import requests

def download(url, agent="python bot",num_retries=2):
    headers = {"user-agent":agent}
    resp = requests.request("get",url, headers=headers)
    
    if 500<= resp.status_code <600 and num_retries>0:
            print(resp.code, resp.reason)
            return download(url,num_retries=num_retries-1)
        
    return resp;

# %%
#requests 크롤링 하는 방법~
agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36"
html = download("https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=zzzzz",agent=agent)

# %%
html.text
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="zzzzz : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'zzzzz\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'zzzzz\'의 네이버 통합검색 결과입니다."> <title>zzzzz : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_140327.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_180712.css"> <link rel="stylesheet" type="text/cs
# ...

# %%
html.encoding
# Out:
# 'UTF-8'

# %%
from urllib import parse

# %%
parse.quote("한글")
# Out:
# '%ED%95%9C%EA%B8%80'

# %%
url = "https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query="+parse.quote("고려대")

# %%
agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36"
html = download(url,agent=agent)

# %%
html.text
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="고려대 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'고려대\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'고려대\'의 네이버 통합검색 결과입니다."> <title>고려대 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_140327.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_180712.css"> <link rel="stylesheet" type="text/css" href=
# ...

# %%
import json

# %%
params = { "where":"nexearch",
           "sm":"top_hty",
           "fbm":1,
           "ie":"utf8",
           "query":parse.quote("고려대")}
url = "https://search.naver.com/search.naver?"

# %%
params
# Out:
# {'where': 'nexearch',
#  'sm': 'top_hty',
#  'fbm': 1,
#  'ie': 'utf8',
#  'query': '%EA%B3%A0%EB%A0%A4%EB%8C%80'}

# %%
jsonParams = json.dumps(params)

# %%
jsonParams
# Out:
# '{"where": "nexearch", "sm": "top_hty", "fbm": 1, "ie": "utf8", "query": "%EA%B3%A0%EB%A0%A4%EB%8C%80"}'

# %%
paramUrl = parse.urlencode(params)

# %%
paramUrl
# Out:
# 'where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%25EA%25B3%25A0%25EB%25A0%25A4%25EB%258C%2580'

# %%
url
# Out:
# 'https://search.naver.com/search.naver?'

# %%
agent
# Out:
# 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36'

# %%
import requests

def downloadJson(url, agent="python bot", num_retries=2):
    headers = {"User-agent":agent}
    resp = requests.get(paramUrl, headers = headers)
    
    if 500 <=req.status_code < 600 and num_retries>0:
        print ("error:", req.status_code, req.reason)
        return download(url,num_retries=(num_retries-1))
    
    return req

html = download(url+paramUrl)

html.text
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="%EA%B3%A0%EB%A0%A4%EB%8C%80 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'%EA%B3%A0%EB%A0%A4%EB%8C%80\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'%EA%B3%A0%EB%A0%A4%EB%8C%80\'의 네이버 통합검색 결과입니다."> <title>%EA%B3%A0%EB%A0%A4%EB%8C%80 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_140327.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pst
# ...

# %%
def downloadGet(url,agent="python", num_retries=2):
    headers = {"User-agent":agent}
    
    req = requests.get(url,params = {"q":"한글", "ie":"utf-8", "oe":"utf-8"}, headers=headers)
    
    if 500<=req.status_code < 600 and num_retries >0:
        print("error:", req.status_code, req.reason)
        return downloadGet(url, num_retries=(num_retries-1))
    
    return req

html = download("http://www.google.com/search")

html.url
# Out:
# 'http://www.google.com/webhp'

# %%
agent
# Out:
# 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.99 Safari/537.36'

# %% [markdown]
# # 크롤링

# %%
#beautifulSoup 은 html 파싱을 위한 library

# %%
# !pip install beautifulsoup4
# Out:
# ...
# distributed 1.21.8 requires msgpack, which is not installed.

# %%
from bs4 import BeautifulSoup

# %%
html = """
    <html>
        <head></head>
        <body>
            <div id="wrap">
                <p class="content">
                    <a href="_blank">Click</a>
                </p>
            </div>
        </body>
    </html>
"""

# %%
doc = BeautifulSoup(html,"lxml")

# %%
type(doc)
# Out:
# bs4.BeautifulSoup

# %%
doc.contents
# Out:
# [<html>
#  <head></head>
#  <body>
#  <div id="wrap">
#  <p class="content">
#  <a href="_blank">Click</a>
#  </p>
#  </div>
#  </body>
#  </html>, '\n']

# %%
doc.div["id"]
# Out:
# 'wrap'

# %%
doc.p["class"]
# Out:
# ['content']

# %%
doc.a["href"]
# Out:
# '_blank'

# %%
doc.a.attrs
# Out:
# {'href': '_blank'}

# %%
doc.a
# Out:
# <a href="_blank">Click</a>

# %%
doc = BeautifulSoup(html.text, "lxml")

# %%
doc.find("a")
# Out:
# <a href="#content">본문 바로가기</a>

# %%
doc.find_all("a")
# Out:
# [<a href="#content">본문 바로가기</a>,
#  <a class="common_pc logo_link" href="https://www.naver.com"><img alt="네이버" height="16" src="https://ssl.pstatic.net/sstatic/search/pc/img/naver_logo.png" width="90"/></a>,
#  <a class="common_m logo_link" href="https://m.naver.com"><img alt="네이버" height="16" src="https://ssl.pstatic.net/sstatic/search/pc/img/naver_logo.png" width="90"/></a>,
#  <a class="nav_link" href="https://www.naver.com">네이버홈</a>,
#  <a class="nav_link" href="https://help.naver.com">네이버 고객센터</a>,
#  <a class="link_prev" href="javascript:{history.back();}">이전 페이지</a>,
#  <a class="link_home" href="https://www.naver.com">네이버 홈</a>,
#  <a class="link_prev" href="javascript:{history.back();}">이전 페이지</a>,
#  <a class="link_home" href="https://m.naver.com">네이버 홈</a>,
#  <a class="link_naver" href="http://www.navercorp.com" target="_blank">NAVER Corp.</a>]

# %%
aList=doc.find_all("a")

# %%
len(aList)
# Out:
# 10

# %%
for row in aList:
    print(type(row),row.attrs["href"])
# Out:
# <class 'bs4.element.Tag'> #content
# <class 'bs4.element.Tag'> https://www.naver.com
# <class 'bs4.element.Tag'> https://m.naver.com
# <class 'bs4.element.Tag'> https://www.naver.com
# <class 'bs4.element.Tag'> https://help.naver.com
# <class 'bs4.element.Tag'> javascript:{history.back();}
# <class 'bs4.element.Tag'> https://www.naver.com
# <class 'bs4.element.Tag'> javascript:{history.back();}
# <class 'bs4.element.Tag'> https://m.naver.com
# <class 'bs4.element.Tag'> http://www.navercorp.com

# %%
html = requests.get("http://pythonscraping.com/pages/warandpeace.html")

# %%
doc = BeautifulSoup(html.text, "lxml")

# %%
div = doc.find("div", id="text")
print(div.get_text())
# Out:
# "Well, Prince, so Genoa and Lucca are now just family estates of the
# Buonapartes. But I warn you, if you don't tell me that this means war,
# if you still try to defend the infamies and horrors perpetrated by
# that Antichrist- I really believe he is Antichrist- I will have
# nothing more to do with you and you are no longer my friend, no longer
# my 'faithful slave,' as you call yourself! But how do you do? I see
# I have frightened you- sit down and tell me all the news."
#
# It was in July, 1805, and the speaker was the well-known Anna
# Pavlovna Scherer, maid of honor and favorite of the Empress Marya
# Fedorovna. With these words she greeted Prince Vasili Kuragin, a man
# of high rank and importance, who was the first to arrive at her
# reception. Anna Pavlovna had had a cough for some days. She was, as
# she said, suffering from la grippe; grippe being then a new word in
# St. Petersburg, used only by the elite.
#
# ...
